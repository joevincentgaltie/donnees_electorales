# %% [markdown]
# ### Import

# %%
import pandas as pd 
import numpy as np

# %%
#fonctions utiles pour présidentielles 

Base = ['Code du département', 'Libellé du département',
       'Code de la circonscription', 'Libellé de la circonscription',
       'Code de la commune', 'Libellé de la commune', 'Code du b.vote',
       'Inscrits', 'Abstentions', '% Abs/Ins', 'Votants', '% Vot/Ins',
       'Blancs', '% Blancs/Ins', '% Blancs/Vot', 'Nuls', '% Nuls/Ins',
       '% Nuls/Vot', 'Exprimés', '% Exp/Ins', '% Exp/Vot']
Candidat = [ 'N°Panneau', 'Sexe',
       'Nom', 'Prénom', 'Voix', '% Voix/Ins', '% Voix/Exp']

#function to fill the columns index,

def fill_columns_index (shape) : 
    columns = Base.copy() 
    i = 0
    while len(columns) < shape : 
        #adding the candidat columns plus identifier 
        i += 1
        columns.extend([ ele + str(i) for ele in Candidat])
    return columns



#extracting Base data, and candidates data one candidate by one candidate  and merge it iteratively to a single dataframe
def extract_data(df, shape) :
    columns = fill_columns_index(shape)
    df.columns = columns
    df_base = df[Base]
  #iterating over 7 columns of candidates data starting from 19th column
    for i in range(21, shape, 7):
        df_candidat = df[columns[i:i+7]]
        df_candidat.columns = Candidat
        df_candidat = df_candidat.fillna(method='ffill')
        df_candidat = df_candidat.fillna(method='bfill')
        df_candidat = df_candidat.fillna(0)
        df_candidat = df_candidat.reset_index(drop=True)
        df_candidat = df_candidat.drop(['N°Panneau'], axis=1)
        df_candidat = df_candidat.drop(['Sexe'], axis=1)
        if i == 21:
            df_new= pd.concat([df_base, df_candidat], axis=1)
        else:
            df_new = pd.concat([df_new, pd.concat([df_base, df_candidat], axis=1)], axis=0)
    
    return df_new

# %% [markdown]
# ## <center> **`Présidentielles`**

# %% [markdown]
# ## `Présidentielles : 2022`

# %% [markdown]
# ### **Tour 1**

# %%
file='data/resultats-par-niveau-burvot-t1-france-entiere.xlsx'
df=pd.read_excel(file)

# %%
df.columns[:30]
# Out:
# Index(['Code du département', 'Libellé du département',
#        'Code de la circonscription', 'Libellé de la circonscription',
#        'Code de la commune', 'Libellé de la commune', 'Code du b.vote',
#        'Inscrits', 'Abstentions', '% Abs/Ins', 'Votants', '% Vot/Ins',
#        'Blancs', '% Blancs/Ins', '% Blancs/Vot', 'Nuls', '% Nuls/Ins',
#        '% Nuls/Vot', 'Exprimés', '% Exp/Ins', '% Exp/Vot', 'N°Panneau', 'Sexe',
#        'Nom', 'Prénom', 'Voix', '% Voix/Ins', '% Voix/Exp', 'Unnamed: 28',
#        'Unnamed: 29'],
#       dtype='object')

# %%
raw_2022_T1 = extract_data(df, df.shape[1])
raw_2022_T1["Election"] = "Presidentielle 2022"
raw_2022_T1["Tour"]= 1

# %% [markdown]
# ### **Tour 2**

# %%
file = 'data/resultats-par-niveau-burvot-t2-france-entiere.csv'
df = pd.read_csv(file, sep=';',encoding='latin-1', header = None, skiprows=1)
raw_2022_T2 = extract_data(df, df.shape[1])
# Out:
# /var/folders/rc/0g2xxgc57fq40kc5jwsm7h_c0000gn/T/ipykernel_40989/1718399321.py:2: DtypeWarning: Columns (0,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep=';',encoding='latin-1', header = None, skiprows=1)

# %%
raw_2022_T2
# Out:
#       Code du département           Libellé du département  \
# 0                      01                              Ain
# 1                      01                              Ain
# 2                      01                              Ain
# 3                      01                              Ain
# 4                      01                              Ain
# ...                   ...                              ...
# 69677                  ZZ  Français établis hors de France
# 69678                  ZZ  Français établis hors de France
# 69679                  ZZ  Français établis hors de France
# 69680                  ZZ  Français établis hors de France
# 69681                  ZZ  Français établis hors de France
#
#        Code de la circonscription Libellé de la circonscription  \
# 0                               4          4ème circonscription
# 1                               5          5ème circonscription
# ...

# %%
raw_2022_T2["Election"] = "Presidentielle 2022"
raw_2022_T2["Tour"]= 2

# %% [markdown]
# ## `Présidentielles :2017`

# %% [markdown]
# ### **Tour 1**

# %%
file = "data/PR17_BVot_T1_FE.csv"

df = pd.read_csv(file, sep=";", encoding="latin-1",header=None, skiprows=1)
print("the shape of the dataframe is: ", df.shape)
# Out:
# the shape of the dataframe is:  (69242, 98)
# /var/folders/rc/0g2xxgc57fq40kc5jwsm7h_c0000gn/T/ipykernel_40989/1839127520.py:3: DtypeWarning: Columns (0,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep=";", encoding="latin-1",header=None, skiprows=1)

# %%
df
# Out:
#        0                                1   2                      3    4   \
# 0       1                              Ain   4   4ème circonscription    1
# 1       1                              Ain   5   5ème circonscription    2
# 2       1                              Ain   5   5ème circonscription    4
# 3       1                              Ain   5   5ème circonscription    4
# 4       1                              Ain   5   5ème circonscription    4
# ...    ..                              ...  ..                    ...  ...
# 69237  ZZ  Français établis hors de France  11  11ème circonscription  226
# 69238  ZZ  Français établis hors de France  10  10ème circonscription  227
# 69239  ZZ  Français établis hors de France   7   7ème circonscription  228
# 69240  ZZ  Français établis hors de France   6   6ème circonscription  229
# 69241  ZZ  Français établis hors de France  11  11ème circonscription  231
#
# ...

# %%
raw_T1_2017 = extract_data(df, df.shape[1])
raw_T1_2017["Election"] = "Presidentielle 2017"
raw_T1_2017["Tour"]= 1

# %% [markdown]
# ### **Tour 2**

# %%
file = "data/PR17_BVot_T2_FE.csv"

df = pd.read_csv(file, sep=";", encoding="latin-1",header=None, skiprows=1)
print("the shape of the dataframe is: ", df.shape)
# Out:
# the shape of the dataframe is:  (69242, 35)
# /var/folders/rc/0g2xxgc57fq40kc5jwsm7h_c0000gn/T/ipykernel_40989/1496989987.py:3: DtypeWarning: Columns (0,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep=";", encoding="latin-1",header=None, skiprows=1)

# %%
raw_T2_2017 = extract_data(df, df.shape[1])
raw_T2_2017["Election"] = "Presidentielle 2017"
raw_T2_2017["Tour"]= 2

# %%
raw_T2_2017
# Out:
#       Code du département           Libellé du département  \
# 0                      01                              Ain
# 1                      01                              Ain
# 2                      01                              Ain
# 3                      01                              Ain
# 4                      01                              Ain
# ...                   ...                              ...
# 69237                  ZZ  Français établis hors de France
# 69238                  ZZ  Français établis hors de France
# 69239                  ZZ  Français établis hors de France
# 69240                  ZZ  Français établis hors de France
# 69241                  ZZ  Français établis hors de France
#
#        Code de la circonscription Libellé de la circonscription  \
# 0                               4          4ème circonscription
# 1                               5          5ème circonscription
# ...

# %% [markdown]
# ## ` Présidentielles : 2012`

# %% [markdown]
# ### **Tour 1 & 2**

# %%
file='data/PR12_Bvot_T1T2.csv'
df = pd.read_csv(file, sep=";", encoding="latin-1")
# Out:
# /var/folders/rc/0g2xxgc57fq40kc5jwsm7h_c0000gn/T/ipykernel_40989/2756794556.py:2: DtypeWarning: Columns (1,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep=";", encoding="latin-1")

# %%
df
# Out:
#         1  ZA  101           Les Abymes  01  01.1 0001  476  266  249   2  \
# 0       1  ZA  101           Les Abymes   1     1    1  476  266  249   3
# 1       1  ZA  101           Les Abymes   1     1    1  476  266  249   4
# 2       1  ZA  101           Les Abymes   1     1    1  476  266  249   5
# 3       1  ZA  101           Les Abymes   1     1    1  476  266  249   9
# 4       1  ZA  101           Les Abymes   1     1    1  476  266  249  11
# ...    ..  ..  ...                  ...  ..   ...  ...  ...  ...  ...  ..
# 815178  2  95  680      Villiers-le-Bel   8    35   13  655  490  469  11
# 815179  2  95  682      Villiers-le-Sec   9    15    1   95   87   83   4
# 815180  2  95  682      Villiers-le-Sec   9    15    1   95   87   83  11
# 815181  2  95  690  Wy-dit-Joli-Village   1    16    1  279  249  240   4
# 815182  2  95  690  Wy-dit-Joli-Village   1    16    1  279  249  240  11
#
#              JOLY       Eva JOLY.1    7
# ...

# %%
Colonnes = ['Tour',
'Code du département',
'Code de la commune',
'Libellé de la commune',
'Code de la circonscription',
'Code du canton',
'Code du b.vote',
'Inscrits',
'Votants',
'Exprimés',
'N°Panneau',
'Nom',
'Prénom',
'Nuance',
'Voix']

# %%
df.columns = Colonnes

# %%
raw_2012_T1T2 = df
raw_2012_T1T2["Election"] = "Presidentielle 2012"

# %% [markdown]
# ## `Présidentielles : 2007`

# %% [markdown]
# ### **Tour 1 & 2**

# %%
file='data/PR07_Bvot_T1T2.csv'
df = pd.read_csv(file, sep=";", encoding="latin-1",skiprows=17,header=None)
# Out:
# /var/folders/rc/0g2xxgc57fq40kc5jwsm7h_c0000gn/T/ipykernel_40989/3303136723.py:2: DtypeWarning: Columns (1,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep=";", encoding="latin-1",skiprows=17,header=None)

# %%
df
# Out:
#         0   1    2                        3     4    5    6    7   8   \
# 0        1   1    1  L'Abergement-Clémenciat  0001  596  528  522   5
# 1        1   1    1  L'Abergement-Clémenciat  0001  596  528  522   2
# 2        1   1    1  L'Abergement-Clémenciat  0001  596  528  522   3
# 3        1   1    1  L'Abergement-Clémenciat  0001  596  528  522  11
# 4        1   1    1  L'Abergement-Clémenciat  0001  596  528  522   7
# ...     ..  ..  ...                      ...   ...  ...  ...  ...  ..
# 918633   2  ZM  517                 TSINGONI    73  694  296  293  12
# 918634   2  ZM  517                 TSINGONI    74  635  236  231   8
# 918635   2  ZM  517                 TSINGONI    74  635  236  231  12
# 918636   2  ZM  517                 TSINGONI    99  175   89   88   8
# 918637   2  ZM  517                 TSINGONI    99  175   89   88  12
#
#                  9             10    11   12
# 0              BOVÉ          José  BOVE    5
# ...

# %%
Colonnes = ['Tour',
'Code du département',
'Code de la commune',
'Libellé de la commune',
'Code du b.vote',
'Inscrits',
'Votants',
'Exprimés',
'N°Panneau',
'Nom',
'Prénom',
'Nuance',
'Voix']

df.columns = Colonnes

# %%
raw_2007_T1T2 = df

# %%
raw_2007_T1T2
# Out:
#         Tour Code du département  Code de la commune    Libellé de la commune  \
# 0          1                   1                   1  L'Abergement-Clémenciat
# 1          1                   1                   1  L'Abergement-Clémenciat
# 2          1                   1                   1  L'Abergement-Clémenciat
# 3          1                   1                   1  L'Abergement-Clémenciat
# 4          1                   1                   1  L'Abergement-Clémenciat
# ...      ...                 ...                 ...                      ...
# 918633     2                  ZM                 517                 TSINGONI
# 918634     2                  ZM                 517                 TSINGONI
# 918635     2                  ZM                 517                 TSINGONI
# 918636     2                  ZM                 517                 TSINGONI
# 918637     2                  ZM                 517                 TSINGONI
#
# ...

# %%
raw_2012_T1T2["Election"] = "Presidentielle 2007"

# %% [markdown]
# ## <center> **`Législatives`**

# %% [markdown]
# ## **`Législatives : 2022`**

# %% [markdown]
# ### **Tour 1**

# %%
file='data/T1_bueau_leg_2022.csv'
df = pd.read_csv(file, sep=";", encoding="latin-1", names = list(range(197)))
# Out:
# /var/folders/rc/0g2xxgc57fq40kc5jwsm7h_c0000gn/T/ipykernel_40989/1982446982.py:2: DtypeWarning: Columns (0,2,4,6,7,8,10,12,15,18,21,26,126,127,128,129,131,132,134,135,136,137,139,140,142,143,144,145,147,148,150,151,152,153,155,156,158,159,160,161,163,164,166,167,168,169,171,172,174,175,176,177,179,180,182,183,184,185,187,188,190,191,192,193,195,196) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep=";", encoding="latin-1", names = list(range(197)))

# %%
df
# Out:
#                        0                                1    \
# 0      Code du département           Libellé du département
# 1                       01                              Ain
# 2                       01                              Ain
# 3                       01                              Ain
# 4                       01                              Ain
# ...                    ...                              ...
# 69678                   ZZ  Français établis hors de France
# 69679                   ZZ  Français établis hors de France
# 69680                   ZZ  Français établis hors de France
# 69681                   ZZ  Français établis hors de France
# 69682                   ZZ  Français établis hors de France
#
#                               2                              3    \
# 0      Code de la circonscription  Libellé de la circonscription
# 1                              04           4ème circonscription
# ...

# %%
df.loc[0,:].to_list()[:32]
# Out:
# ['Code du département',
#  'Libellé du département',
#  'Code de la circonscription',
#  'Libellé de la circonscription',
#  'Code de la commune',
#  'Libellé de la commune',
#  'Code du b.vote',
#  'Inscrits',
#  'Abstentions',
#  '% Abs/Ins',
#  'Votants',
#  '% Vot/Ins',
#  'Blancs',
#  '% Blancs/Ins',
#  '% Blancs/Vot',
#  'Nuls',
#  '% Nuls/Ins',
#  '% Nuls/Vot',
#  'Exprimés',
#  '% Exp/Ins',
#  '% Exp/Vot',
#  'N°Panneau',
#  'Sexe',
#  'Nom',
#  'Prénom',
#  'Nuance',
#  'Voix',
#  '% Voix/Ins',
#  '% Voix/Exp',
#  nan,
#  nan,
#  nan]

# %%
Base = ['Code du département',
        'Libellé du département',
        'Code de la circonscription',
        'Libellé de la circonscription',
        'Code de la commune',
        'Libellé de la commune',
        'Code du b.vote',
        'Inscrits',
        'Abstentions',
        '% Abs/Ins',
        'Votants',
        '% Vot/Ins',
        'Blancs',
        '% Blancs/Ins',
        '% Blancs/Vot',
        'Nuls',
        '% Nuls/Ins',
        '% Nuls/Vot',
        'Exprimés',
        '% Exp/Ins',
        '% Exp/Vot']


Candidat = ['N°Panneau',
            'Sexe',
            'Nom',
            'Prénom',
            'Nuance',
            'Voix',
            '% Voix/Ins',
            '% Voix/Exp']



def fill_columns_index (shape) : 
    columns = Base.copy() 
    i = 0
    while len(columns) < shape : 
        #adding the candidat columns plus identifier 
        i += 1
        columns.extend([ ele + str(i) for ele in Candidat])
    return columns

 #extracting Base data, and candidates data one candidate by one candidate  and merge it iteratively to a single dataframe
def extract_data(df, shape) :
    columns = fill_columns_index(shape)
    df.columns = columns ##change it because of the shape of the dataframe manually set to 200
    df_base = df[Base]
  #iterating over 7 columns of candidates data starting from 19th column
    for i in range(21, shape, 8):
        print(columns[i:i+8])
        df_candidat = df[columns[i:i+8]]
        df_candidat.columns = Candidat
        df_candidat = df_candidat.fillna(method='ffill')
        df_candidat = df_candidat.fillna(method='bfill')
        df_candidat = df_candidat.fillna(0)
        df_candidat = df_candidat.reset_index(drop=True)
        df_candidat = df_candidat.drop(['N°Panneau'], axis=1)
        df_candidat = df_candidat.drop(['Sexe'], axis=1)
        if i == 21:
            df_new= pd.concat([df_base, df_candidat], axis=1)
        else:
            df_new = pd.concat([df_new, pd.concat([df_base, df_candidat], axis=1)], axis=0)
    
    return df_new

# %%
df = df.drop([0], axis=0)

# %%
df=extract_data(df, df.shape[1])
# Out:
# ['N°Panneau1', 'Sexe1', 'Nom1', 'Prénom1', 'Nuance1', 'Voix1', '% Voix/Ins1', '% Voix/Exp1']
# ['N°Panneau2', 'Sexe2', 'Nom2', 'Prénom2', 'Nuance2', 'Voix2', '% Voix/Ins2', '% Voix/Exp2']
# ['N°Panneau3', 'Sexe3', 'Nom3', 'Prénom3', 'Nuance3', 'Voix3', '% Voix/Ins3', '% Voix/Exp3']
# ['N°Panneau4', 'Sexe4', 'Nom4', 'Prénom4', 'Nuance4', 'Voix4', '% Voix/Ins4', '% Voix/Exp4']
# ['N°Panneau5', 'Sexe5', 'Nom5', 'Prénom5', 'Nuance5', 'Voix5', '% Voix/Ins5', '% Voix/Exp5']
# ['N°Panneau6', 'Sexe6', 'Nom6', 'Prénom6', 'Nuance6', 'Voix6', '% Voix/Ins6', '% Voix/Exp6']
# ['N°Panneau7', 'Sexe7', 'Nom7', 'Prénom7', 'Nuance7', 'Voix7', '% Voix/Ins7', '% Voix/Exp7']
# ['N°Panneau8', 'Sexe8', 'Nom8', 'Prénom8', 'Nuance8', 'Voix8', '% Voix/Ins8', '% Voix/Exp8']
# ['N°Panneau9', 'Sexe9', 'Nom9', 'Prénom9', 'Nuance9', 'Voix9', '% Voix/Ins9', '% Voix/Exp9']
# ['N°Panneau10', 'Sexe10', 'Nom10', 'Prénom10', 'Nuance10', 'Voix10', '% Voix/Ins10', '% Voix/Exp10']
# ...

# %%
raw_2022_leg_T1 = df
raw_2022_leg_T1["Election"] = "Legislatives 2022"
raw_2022_leg_T1["Tour"] = 1

# %% [markdown]
# ### **Tour 2**

# %%
file='data/T1_bueau_leg_2022.csv'
df = pd.read_csv(file, sep=";", encoding="latin-1", names = list(range(197)))
df = df.drop([0], axis=0)
df=extract_data(df, df.shape[1])
raw_2022_leg_T2 = df
# Out:
# /var/folders/rc/0g2xxgc57fq40kc5jwsm7h_c0000gn/T/ipykernel_40989/1575366550.py:2: DtypeWarning: Columns (0,2,4,6,7,8,10,12,15,18,21,26,126,127,128,129,131,132,134,135,136,137,139,140,142,143,144,145,147,148,150,151,152,153,155,156,158,159,160,161,163,164,166,167,168,169,171,172,174,175,176,177,179,180,182,183,184,185,187,188,190,191,192,193,195,196) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep=";", encoding="latin-1", names = list(range(197)))
# ['N°Panneau1', 'Sexe1', 'Nom1', 'Prénom1', 'Nuance1', 'Voix1', '% Voix/Ins1', '% Voix/Exp1']
# ['N°Panneau2', 'Sexe2', 'Nom2', 'Prénom2', 'Nuance2', 'Voix2', '% Voix/Ins2', '% Voix/Exp2']
# ['N°Panneau3', 'Sexe3', 'Nom3', 'Prénom3', 'Nuance3', 'Voix3', '% Voix/Ins3', '% Voix/Exp3']
# ['N°Panneau4', 'Sexe4', 'Nom4', 'Prénom4', 'Nuance4', 'Voix4', '% Voix/Ins4', '% Voix/Exp4']
# ['N°Panneau5', 'Sexe5', 'Nom5', 'Prénom5', 'Nuance5', 'Voix5', '% Voix/Ins5', '% Voix/Exp5']
# ...

# %%
raw_2022_leg_T2["Election"] = "Legislatives 2022"
raw_2022_leg_T2["Tour"] = 2

# %% [markdown]
# ## `Législatives 2017`

# %% [markdown]
# ### **Tour 1**

# %%
file = 'data/Leg_2017_Resultats_BVT_T1_c.csv'
df = pd.read_csv(file, sep=";", encoding="latin-1", names = list(range(237)),skiprows=1)
# Out:
# /var/folders/rc/0g2xxgc57fq40kc5jwsm7h_c0000gn/T/ipykernel_40989/1107141887.py:2: DtypeWarning: Columns (0,6,150,151,152,153,155,156,158,159,160,161,163,164,166,167,168,169,171,172,174,175,176,177,179,180,182,183,184,185,187,188,190,191,192,193,195,196,198,199,200,201,203,204,206,207,208,209,211,212,214,215,216,217,219,220,222,223,224,225,227,228,230,231,232,233,235,236) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep=";", encoding="latin-1", names = list(range(237)),skiprows=1)

# %%
df
# Out:
#       0                                1    2                      3    4    \
# 0       1                              Ain    4   4ème circonscription    1
# 1       1                              Ain    5   5ème circonscription    2
# 2       1                              Ain    5   5ème circonscription    4
# 3       1                              Ain    5   5ème circonscription    4
# 4       1                              Ain    5   5ème circonscription    4
# ...    ..                              ...  ...                    ...  ...
# 69237  ZZ  Français établis hors de France   10  10ème circonscription  227
# 69238  ZZ  Français établis hors de France    7   7ème circonscription  228
# 69239  ZZ  Français établis hors de France    6   6ème circonscription  229
# 69240  ZZ  Français établis hors de France   11  11ème circonscription  231
# 69241  ZZ  Français établis hors de France    2   2ème circonscription  232
#
# ...

# %%
#df = df.drop([0], axis=0)
df=extract_data(df, df.shape[1])
raw_2017_leg_T1 = df
# Out:
# ['N°Panneau1', 'Sexe1', 'Nom1', 'Prénom1', 'Nuance1', 'Voix1', '% Voix/Ins1', '% Voix/Exp1']
# ['N°Panneau2', 'Sexe2', 'Nom2', 'Prénom2', 'Nuance2', 'Voix2', '% Voix/Ins2', '% Voix/Exp2']
# ['N°Panneau3', 'Sexe3', 'Nom3', 'Prénom3', 'Nuance3', 'Voix3', '% Voix/Ins3', '% Voix/Exp3']
# ['N°Panneau4', 'Sexe4', 'Nom4', 'Prénom4', 'Nuance4', 'Voix4', '% Voix/Ins4', '% Voix/Exp4']
# ['N°Panneau5', 'Sexe5', 'Nom5', 'Prénom5', 'Nuance5', 'Voix5', '% Voix/Ins5', '% Voix/Exp5']
# ['N°Panneau6', 'Sexe6', 'Nom6', 'Prénom6', 'Nuance6', 'Voix6', '% Voix/Ins6', '% Voix/Exp6']
# ['N°Panneau7', 'Sexe7', 'Nom7', 'Prénom7', 'Nuance7', 'Voix7', '% Voix/Ins7', '% Voix/Exp7']
# ['N°Panneau8', 'Sexe8', 'Nom8', 'Prénom8', 'Nuance8', 'Voix8', '% Voix/Ins8', '% Voix/Exp8']
# ['N°Panneau9', 'Sexe9', 'Nom9', 'Prénom9', 'Nuance9', 'Voix9', '% Voix/Ins9', '% Voix/Exp9']
# ['N°Panneau10', 'Sexe10', 'Nom10', 'Prénom10', 'Nuance10', 'Voix10', '% Voix/Ins10', '% Voix/Exp10']
# ...

# %%
raw_2017_leg_T1["Election"] = "Legislatives 2017"
raw_2017_leg_T1["Tour"] = 1

# %% [markdown]
# ### **Tour 2**

# %%
file = 'data/Leg_2017_Resultats_BVT_T2_c.csv'
df = pd.read_csv(file, sep=";", encoding="latin-1", names = list(range(237)))
df = df.drop([0], axis=0)
df=extract_data(df, df.shape[1])
raw_2017_leg_T2 = df
# Out:
# /var/folders/rc/0g2xxgc57fq40kc5jwsm7h_c0000gn/T/ipykernel_40989/467176188.py:2: DtypeWarning: Columns (0,2,4,6,7,8,10,12,15,18,21,26,38,39,40,41,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep=";", encoding="latin-1", names = list(range(237)))
# ['N°Panneau1', 'Sexe1', 'Nom1', 'Prénom1', 'Nuance1', 'Voix1', '% Voix/Ins1', '% Voix/Exp1']
# ['N°Panneau2', 'Sexe2', 'Nom2', 'Prénom2', 'Nuance2', 'Voix2', '% Voix/Ins2', '% Voix/Exp2']
# ['N°Panneau3', 'Sexe3', 'Nom3', 'Prénom3', 'Nuance3', 'Voix3', '% Voix/Ins3', '% Voix/Exp3']
# ['N°Panneau4', 'Sexe4', 'Nom4', 'Prénom4', 'Nuance4', 'Voix4', '% Voix/Ins4', '% Voix/Exp4']
# ['N°Panneau5', 'Sexe5', 'Nom5', 'Prénom5', 'Nuance5', 'Voix5', '% Voix/Ins5', '% Voix/Exp5']
# ['N°Panneau6', 'Sexe6', 'Nom6', 'Prénom6', 'Nuance6', 'Voix6', '% Voix/Ins6', '% Voix/Exp6']
# ['N°Panneau7', 'Sexe7', 'Nom7', 'Prénom7', 'Nuance7', 'Voix7', '% Voix/Ins7', '% Voix/Exp7']
# ...

# %%
raw_2017_leg_T2["Election"] = "Legislatives 2017"
raw_2017_leg_T2["Tour"] = 2

# %% [markdown]
# ## `Législatives : 2012`

# %% [markdown]
# ### **Tour 1 et 2**

# %%
file = "data/LG12_Bvot_T1T2.csv"
df = pd.read_csv(file, sep=";", encoding="latin-1", names = list(range(237)))
# Out:
# /var/folders/rc/0g2xxgc57fq40kc5jwsm7h_c0000gn/T/ipykernel_40989/1860040836.py:2: DtypeWarning: Columns (0,1,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep=";", encoding="latin-1", names = list(range(237)))

# %%
df
# Out:
#                                                       0    1      2    \
# 0       --  Résultats par bureau de vote Législatives ...  NaN    NaN
# 1       --                                            ...  NaN    NaN
# 2       -- Champ 1  : N° tour                         ...  NaN    NaN
# 3       -- Champ 2  : Code département                ...  NaN    NaN
# 4       -- Champ 3  : Code de la commune              ...  NaN    NaN
# ...                                                   ...  ...    ...
# 868483                                                  2   95  680.0
# 868484                                                  2   95  682.0
# 868485                                                  2   95  682.0
# 868486                                                  2   95  690.0
# 868487                                                  2   95  690.0
#
#                         3    4     5    6      7      8      9    ...  227  \
# ...

# %%
Colonnes = ['Tour',
'Code du département',
'Code de la commune',
'Libellé de la commune',
'Code de la circonscription',
'Code du canton',
'Code du b.vote',
'Inscrits',
'Votants',
'Exprimés',
'N°Panneau',
'Nom',
'Prénom',
'Nuance',
'Voix']

# %%
#drop 18 first rows 
df = df.drop(list(range(18)), axis=0)
df.dropna(axis=1, how='all', inplace=True)
df.columns = Colonnes

# %%
raw_2012_leg_T1T2 = df
raw_2012_leg_T1T2["Election"] = "Legislatives 2012"

# %% [markdown]
# ## `Législatives : 2007`

# %% [markdown]
# ### **Tour 1 et 2**

# %%
file = "data/LG07_Bvot_T1T2.csv"
df = pd.read_csv(file, sep=";", encoding="latin-1", names = list(range(237)))
# Out:
# /var/folders/rc/0g2xxgc57fq40kc5jwsm7h_c0000gn/T/ipykernel_40989/3209020231.py:2: DtypeWarning: Columns (0,1,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep=";", encoding="latin-1", names = list(range(237)))

# %%
df
# Out:
#                                                       0    1      2    \
# 0       --  Résultats par bureau de vote Législatives ...  NaN    NaN
# 1       --                                            ...  NaN    NaN
# 2       --                                            ...  NaN    NaN
# 3       -- Champ 1  : N° tour                         ...  NaN    NaN
# 4       -- Champ 2  : Code département                ...  NaN    NaN
# ...                                                   ...  ...    ...
# 965301                                                  2   ZM  517.0
# 965302                                                  2   ZM  517.0
# 965303                                                  2   ZM  517.0
# 965304                                                  2   ZM  517.0
# 965305                                                  2   ZM  517.0
#
#              3    4      5      6      7     8          9    ... 227 228  229  \
# ...

# %%
Colonnes = ['Tour',
'Code du département',
'Code de la commune',
'Libellé de la commune',
'Code du b.vote',
'Inscrits',
'Votants',
'Exprimés',
'N°Panneau',
'Nom',
'Prénom',
'Nuance',
'Voix']

df = df.drop(list(range(18)), axis=0)
df.dropna(axis=1, how='all', inplace=True)
df.columns = Colonnes

# %%
raw_2007_leg_T1T2 = df

raw_2007_leg_T1T2["Election"] = "Legislatives 2007"

# %% [markdown]
# ***
# ***

# %% [markdown]
# Nous disposons à ce niveau des datasets suivants :
#
# - `Présidentielles 2022` :
#     - raw_2022_T1
#     - raw_2022_T2
# - `Législatives 2022` :
#     - raw_2022_leg_T1
#     - raw_2022_leg_T2
#
# - `Présidentielles 2017` :
#     - raw_T1_2017
#     - raw_T2_2017
# - `Législatives 2017` :
#     - raw_2017_leg_T1
#     - raw_2017_leg_T2
#
# - `Présidentielles 2012` :
#     - raw_2012_T1T2
# - `Législatives 2012` :
#     - raw_2012_leg_T1T2
#
# - `Présidentielles 2007` :
#     - raw_2007_T1T2
# - `Législatives 2097` :
#     - raw_2007_leg_T1T2

# %%
def concatenation(df1,df2) : 
    print("df1 shape is ", df1.shape)
    print("")
    print("df2 shape is ", df2.shape)

    df = pd.concat([df1,df2], axis = 0)

    print("df shape is ", df.shape)
    print("good concat on rows: ", df.shape[0] == df1.shape[0] + df2.shape[0])
    print("good concat on columns: ", (df.shape[1] == df1.shape[1],  df.shape[1] == df2.shape[1]))

    return df

# %%
pres_2022_T1T2 = concatenation(raw_2022_T1,raw_2022_T2)
# Out:
# df1 shape is  (836184, 28)
#
# df2 shape is  (139364, 28)
# df shape is  (975548, 28)
# good concat on rows:  True
# good concat on columns:  (True, True)

# %%
leg_2022_T1T2 = concatenation(raw_2022_leg_T1, raw_2022_leg_T2 )
# Out:
# df1 shape is  (1533026, 29)
#
# df2 shape is  (1533026, 29)
# df shape is  (3066052, 29)
# good concat on rows:  True
# good concat on columns:  (True, True)

# %%
pres_2017_T1T2 = concatenation(raw_T1_2017,raw_T2_2017)
# Out:
# df1 shape is  (761662, 28)
#
# df2 shape is  (138484, 28)
# df shape is  (900146, 28)
# good concat on rows:  True
# good concat on columns:  (True, True)

# %%
leg_2017_T1T2 = concatenation(raw_2017_leg_T1, raw_2017_leg_T2 )
# Out:
# df1 shape is  (1869534, 29)
#
# df2 shape is  (1856736, 29)
# df shape is  (3726270, 29)
# good concat on rows:  True
# good concat on columns:  (True, True)

# %% [markdown]
# Nous disposons à ce niveau des datasets suivants :
#
# - `Présidentielles 2022` :
#     - pres_2022_T1T2
# - `Législatives 2022` :
#     - leg_2022_T1T1
# - `Présidentielles 2017` :
#     - pres_2017_T1T2
# - `Législatives 2017` :
#     - leg_2017_T1T1
# - `Présidentielles 2012` :
#     - raw_2012_T1T2
# - `Législatives 2012` :
#     - raw_2012_leg_T1T2
#
# - `Présidentielles 2007` :
#     - raw_2007_T1T2
# - `Législatives 2097` :
#     - raw_2007_leg_T1T2

# %%
#function that takes several dataframe and gives the common columns
from functools import reduce 

def common_columns(*args):
    common = set(args[0].columns)
    for i in range(1, len(args)):
        common = common.intersection(set(args[i].columns))
    return list(common)

common_columns(raw_2022_leg_T1, raw_2022_leg_T2, raw_2017_leg_T1, raw_2017_leg_T2, raw_2012_leg_T1T2, raw_2007_leg_T1T2)


result = list(reduce(set.intersection, map(set,[raw_2022_leg_T1.columns, 
                                                raw_2022_leg_T2.columns, 
                                                raw_2017_leg_T1.columns, 
                                                raw_2017_leg_T2.columns, 
                                                raw_2012_leg_T1T2.columns, 
                                                raw_2007_leg_T1T2.columns])))

# %%
result
# Out:
# ['Code du b.vote',
#  'Nuance',
#  'Election',
#  'Code de la commune',
#  'Inscrits',
#  'Libellé de la commune',
#  'Prénom',
#  'Tour',
#  'Exprimés',
#  'Voix',
#  'Code du département',
#  'Votants',
#  'Nom']

# %%
dfs = [pres_2022_T1T2,leg_2022_T1T2,pres_2017_T1T2,leg_2017_T1T2,raw_2012_leg_T1T2,raw_2007_leg_T1T2]

df = pd.DataFrame(columns= result)
for ele in dfs : 
    df = pd.concat([df,ele], axis = 0)

df=df[["Election", "Tour","Code du département","Code de la commune","Libellé de la commune", "Code du b.vote", "Inscrits", "Votants", "Exprimés", "Nom", "Prénom", "Nuance", "Voix"]]

# %% [markdown]
# ***
# ***

# %%
all_results = df

# %%
all_results
# Out:
#                    Election Tour Code du département Code de la commune  \
# 0       Presidentielle 2022    1                  01                  1
# 1       Presidentielle 2022    1                  01                  2
# 2       Presidentielle 2022    1                  01                  4
# 3       Presidentielle 2022    1                  01                  4
# 4       Presidentielle 2022    1                  01                  4
# ...                     ...  ...                 ...                ...
# 965301    Legislatives 2007    2                  ZM              517.0
# 965302    Legislatives 2007    2                  ZM              517.0
# 965303    Legislatives 2007    2                  ZM              517.0
# 965304    Legislatives 2007    2                  ZM              517.0
# 965305    Legislatives 2007    2                  ZM              517.0
#
#           Libellé de la commune Code du b.vote Inscrits Votants Exprimés  \
# ...

# %% [markdown]
# ### <center> **`Nuances`**

# %% [markdown]
# ### compléter les nuances manquantes

# %%
all_results[all_results["Nuance"].isna()][['Nom']].drop_duplicates()["Nom"].to_list()
# Out:
# ['ARTHAUD',
#  'ROUSSEL',
#  'MACRON',
#  'LASSALLE',
#  'LE PEN',
#  'ZEMMOUR',
#  'MÉLENCHON',
#  'HIDALGO',
#  'JADOT',
#  'PÉCRESSE',
#  'POUTOU',
#  'DUPONT-AIGNAN',
#  nan,
#  'HAMON',
#  'CHEMINADE',
#  'ASSELINEAU',
#  'FILLON']

# %%
Nuances_manquantes = {'ARTHAUD' : "LO",
 'ROUSSEL' : "PC",
 'MACRON' : "LREM",
 'LASSALLE' : "LIOT",
 'LE PEN' : "RN",
 'ZEMMOUR' : "REC",
 'MÉLENCHON' : "LFI",
 'HIDALGO' : "PS",
 'JADOT' : "EELV",
 'PÉCRESSE' : "LR",
 'POUTOU' : "NPA",
 'DUPONT-AIGNAN' : "DLF",
 'HAMON' : "PS",
 'CHEMINADE' : "SP",
 'ASSELINEAU' : "UPR",
 'FILLON' : "LR"
}

for key, value in Nuances_manquantes.items():
    all_results.loc[all_results["Nom"] == key, "Nuance"] = value

# %%
all_results[all_results["Nuance"]=="MAJ"][["Nom","Prénom"]].drop_duplicates()
# Out:
#                       Nom        Prénom
# 36593              SALLES          Rudy
# 44320               LAVIS     Christian
# 56899            BUCAILLE     Véronique
# 56914            HOCQUARD     Françoise
# 69076            RABINEAU  Jean-Jacques
# ...                   ...           ...
# 803398           POURDIEU     Stéphanie
# 816280             PERNES        Claude
# 843388  CHARETIERS-SIOUFI       Suzanne
# 844398             MUELLE       Danièle
# 844399            MOLINIE         Louis
#
# [99 rows x 2 columns]

# %%
## ce classement est subjectif, il peut etre revu
nuances_gathered ={'LO' : "EXTG ",
 'PC' : "EXTG",
 'LREM' : "CENTRE-DROIT",
 'LIOT':"CENTRE-DROIT",
 'RN' : "EXTD",
 'REC' : "EXTD",
 'LFI' : "EXTG",
 'PS' : "GCHE",
 'EELV' : "ECO",
 'LR' : "DRTE",
 'NPA' : "EXTG",
 'DLF' : "EXTD",
 'DXG' : "EXTG",
 'DVG' : "GCHE",
 'DIV' : "DIVERS",
 'REG' : "REG",
 'ECO' : "ECO",
 'NUP' : "EXTG",
 'RDG' : "CENTRE-GCHE",
 'ENS' : "CENTRE-DROIT",
 'DVC' : "CENTRE",
 'DSV' : "EXTD",
 'DVD' : "DRTE",
 'UDI' : "CENTRE-DROIT",
 'DXD' : "EXTD",
 'SP' : "EXTD",
 'UPR' : "EXTD",
 'EXG' : "EXTG",
 'FI' : "EXTG",
 'COM': "EXTG",
 'SOC' : "GCHE",
 'MDM' : "CENTRE",
 'REM' : "CENTRE-DROIT",
 'FN' : "EXTD",
 'EXD' : "EXTD",
 'VEC' : "ECO",
 'UMP' : "DRTE",
 'AUT' : "DIVERS",
 'NCE' : "CENTRE-DROIT",
 'PRV' :"CENTRE-DROIT",
 'FG' : "EXTG",
 'CEN' : "CENTRE",
 'ALLI' : "CENTRE",
 'UDFD': "CENTRE-DROIT",
 'CPNT' : "DRTE",
 'MPF' : "EXTD",
 'MAJ': "DRTE"}
 
all_results["Orientation"] = ""

for key, value in nuances_gathered.items():
    all_results.loc[all_results["Nuance"] == key, "Nuance"] = value

# %%
all_results["Code de la commune"].fillna(0, inplace=True)
all_results["Code de la commune"].replace("nan", 0, inplace=True)
all_results["Code de la commune"] = all_results["Code de la commune"].apply(lambda  x : str(int(x)).zfill(3))

all_results["Code du département"] = all_results["Code du département"].apply(lambda  x : str(x).zfill(2))

all_results["Code INSEE"]=all_results["Code du département"]+ all_results["Code de la commune"]

all_results['Code du b.vote'] = all_results['Code du b.vote'].apply(lambda x: str(x).zfill(4))

# %% [markdown]
# ### <center> Adding : `Bureaux de vote`

# %%
file = "data/bureaux-vote-france-2017.csv"
df = pd.read_csv(file, sep=";", encoding="utf-8")

# %%
df['Code INSEE'].fillna(0, inplace=True)
df['Code INSEE'].value_counts().sort_values(ascending=False)
# Out:
# 0.0        539
# 31555.0    263
# 6088.0     251
# 44109.0    200
# 67482.0    143
#           ...
# 24010.0      1
# 24009.0      1
# 19168.0      1
# 19125.0      1
# 26138.0      1
# Name: Code INSEE, Length: 33384, dtype: int64

# %%
df["Code INSEE"]=df["Code INSEE"].apply(lambda  x : str(int(x)).zfill(5))

# %% [markdown]
# ### Saving

# %%
all_results.to_csv("data/all_results.csv", sep=";", index=False)

# %% [markdown]
# ### Merging

# %%
all_results["Code du b.vote"]
df["Code Bureau Vote"]
# Out:
# 0        0001
# 1        0001
# 2        0001
# 3        0001
# 4        0001
#          ...
# 65482     NaN
# 65483    0001
# 65484    0001
# 65485    0001
# 65486    0001
# Name: Code Bureau Vote, Length: 65487, dtype: object

# %%
df1 = pd.merge(df, all_results, how='right', left_on=['Code INSEE','Code Bureau Vote'], right_on = ['Code INSEE', 'Code du b.vote'])

# %%
print(df1.shape[0]==all_results.shape[0])
# Out:
# False

# %%
df1.shape
# Out:
# (10504021, 27)

# %%
df1
# Out:
#                  Bureau de vote Code INSEE Code Bureau Vote  \
# 0                           NaN      01001              NaN
# 1         Bureau de vote unique      01002             0001
# 2            Bureau de vote n°1      01004             0001
# 3            Bureau de vote n°2      01004             0002
# 4            Bureau de vote n°3      01004             0003
# ...                         ...        ...              ...
# 10504016                    NaN      ZM517              NaN
# 10504017                    NaN      ZM517              NaN
# 10504018                    NaN      ZM517              NaN
# 10504019                    NaN      ZM517              NaN
# 10504020                    NaN      ZM517              NaN
#
#           Heure d'ouverture  Heure de fermeture  Code Postal  \
# 0                       NaN                 NaN          NaN
# 1                       8.0                19.0       1640.0
# ...

# %%
df1.head()
# Out:
#           Bureau de vote Code INSEE Code Bureau Vote  Heure d'ouverture  \
# 0                    NaN      01001              NaN                NaN
# 1  Bureau de vote unique      01002             0001                8.0
# 2     Bureau de vote n°1      01004             0001                8.0
# 3     Bureau de vote n°2      01004             0002                8.0
# 4     Bureau de vote n°3      01004             0003                8.0
#
#    Heure de fermeture  Code Postal                  Ville  \
# 0                 NaN          NaN                    NaN
# 1                19.0       1640.0  L'Abergement-de-Varey
# 2                19.0       1500.0      Ambérieu-en-Bugey
# 3                19.0       1500.0      Ambérieu-en-Bugey
# 4                19.0       1500.0      Ambérieu-en-Bugey
#
#            Nom Bureau Vote           Adresse  Adresse Substitution  ...  \
# 0                      NaN               NaN                   NaN  ...
# ...

# %%
df1['Code Bureau Vote'].isna().value_counts()
# Out:
# False    8840404
# True     1663617
# Name: Code Bureau Vote, dtype: int64

# %%
df1
# Out:
#                  Bureau de vote Code INSEE Code Bureau Vote  \
# 0                           NaN      01001              NaN
# 1         Bureau de vote unique      01002             0001
# 2            Bureau de vote n°1      01004             0001
# 3            Bureau de vote n°2      01004             0002
# 4            Bureau de vote n°3      01004             0003
# ...                         ...        ...              ...
# 10504016                    NaN      ZM517              NaN
# 10504017                    NaN      ZM517              NaN
# 10504018                    NaN      ZM517              NaN
# 10504019                    NaN      ZM517              NaN
# 10504020                    NaN      ZM517              NaN
#
#           Heure d'ouverture  Heure de fermeture  Code Postal  \
# 0                       NaN                 NaN          NaN
# 1                       8.0                19.0       1640.0
# ...

# %%
df1.to_csv("data/results_avec_bureaux.csv", sep=";", index=False)

# %%
del all_results

# %% [markdown]
# ### `Zoom 94`

# %%
df1["Code du département"]
# Out:
# 0           01
# 1           01
# 2           01
# 3           01
# 4           01
#             ..
# 10504016    ZM
# 10504017    ZM
# 10504018    ZM
# 10504019    ZM
# 10504020    ZM
# Name: Code du département, Length: 10504021, dtype: object

# %%
results_94 = df1[df1["Code du département"]=="94"]

# %%
results_94
# Out:
#                Bureau de vote Code INSEE Code Bureau Vote  Heure d'ouverture  \
# 65292      Bureau de vote n°1      94001             0001                8.0
# 65293      Bureau de vote n°2      94001             0002                8.0
# 65294      Bureau de vote n°3      94001             0003                8.0
# 65295      Bureau de vote n°4      94001             0004                8.0
# 65296      Bureau de vote n°1      94002             0001                8.0
# ...                       ...        ...              ...                ...
# 10499400  Bureau de vote n°45      94081             0045                8.0
# 10499401  Bureau de vote n°46      94081             0046                8.0
# 10499402  Bureau de vote n°46      94081             0046                8.0
# 10499403  Bureau de vote n°47      94081             0047                8.0
# 10499404  Bureau de vote n°47      94081             0047                8.0
#
# ...

# %%
results_vincennes = results_94[results_94["Libellé de la commune"]=="Vincennes"]

# %%
results_vincennes
# Out:
#                Bureau de vote Code INSEE Code Bureau Vote  Heure d'ouverture  \
# 66016      Bureau de vote n°1      94080             0001                8.0
# 66017      Bureau de vote n°2      94080             0002                8.0
# 66018      Bureau de vote n°3      94080             0003                8.0
# 66019      Bureau de vote n°4      94080             0004                8.0
# 66020      Bureau de vote n°5      94080             0005                8.0
# ...                       ...        ...              ...                ...
# 10499308  Bureau de vote n°29      94080             0029                8.0
# 10499309  Bureau de vote n°30      94080             0030                8.0
# 10499310  Bureau de vote n°30      94080             0030                8.0
# 10499311  Bureau de vote n°31      94080             0031                8.0
# 10499312  Bureau de vote n°31      94080             0031                8.0
#
# ...

# %%
#function that prints per bureau de vote the evolution of votes
